# %%
# !pip install keras-metrics
# !pip install patchify
# !pip install segmentation_models

import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm
# Out:
# Collecting keras-metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Keras>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from keras-metrics) (3.2.1)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (13.7.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (3.10.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from Keras>=2.1.5->keras-metrics) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from optree->Keras>=2.1.5->keras-metrics) (4.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->Keras>=2.1.5->keras-metrics) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->Keras>=2.1.5->keras-metrics) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->Keras>=2.1.5->keras-metrics) (0.1.2)
# Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from patchify) (1.26.4)
# Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl.metadata (938 bytes)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet==1.0.0->segmentation_models) (0.22.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.26.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.10.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet==1.0.0->segmentation_models) (3.1.1)
# Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1
# 2024-04-29 03:16:41.600073: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-29 03:16:41.600166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-29 03:16:41.710160: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Segmentation Models: using `tf.keras` framework.

# %%
# https://youtu.be/jvZm8REF2KY
"""
https://www.kaggle.com/humansintheloop/semantic-segmentation-of-aerial-imagery

The dataset consists of aerial imagery of Dubai obtained by MBRSC satellites and annotated with pixel-wise semantic segmentation in 6 classes. The total volume of the dataset is 72 images grouped into 6 larger tiles. The classes are:

Building: #3C1098
Land (unpaved area): #8429F6
Road: #6EC1E4
Vegetation: #FEDD3A
Water: #E2A929
Unlabeled: #9B9B9B

Use patchify....
Tile 1: 797 x 644 --> 768 x 512 --> 6
Tile 2: 509 x 544 --> 512 x 256 --> 2
Tile 3: 682 x 658 --> 512 x 512  --> 4
Tile 4: 1099 x 846 --> 1024 x 768 --> 12
Tile 5: 1126 x 1058 --> 1024 x 1024 --> 16
Tile 6: 859 x 838 --> 768 x 768 --> 9
Tile 7: 1817 x 2061 --> 1792 x 2048 --> 56
Tile 8: 2149 x 1479 --> 1280 x 2048 --> 40
Total 9 images in each folder * (145 patches) = 1305
Total 1305 patches of size 256x256

"""

import os
import cv2
import numpy as np

from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import metrics
from keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = MinMaxScaler()

root_directory = '/kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset'

patch_size = 256

# %%
#Read images from repsective 'images' subdirectory
#As all images are of ddifferent size we have 2 options, either resize or crop
#But, some images are too large and some small. Resizing will change the size of real objects.
#Therefore, we will crop them to a nearest size divisible by 256 and then 
#divide all images into patches of 256x256x3. 
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   #Find all 'images' directories
        images = os.listdir(path)  #List of all image names in this subdirectory
        for i, image_name in enumerate(images):  
            if image_name.endswith(".jpg"):   #Only read jpg images...
               
                image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
                SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                image = Image.fromarray(image)
                image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                image = np.array(image)             
       
                #Extract patches from each image
                print("Now patchifying image:", path+"/"+image_name)
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        
                        single_patch_img = patches_img[i,j,:,:]
                        
                        #Use minmaxscaler instead of just dividing by 255. 
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. 
                        single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
                        image_dataset.append(single_patch_img)
                
  
                
  
 #Now do the same as above for masks
 #For this specific dataset we could have added masks to the above code as masks have extension png
mask_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   #Find all 'images' directories
        masks = os.listdir(path)  #List of all image names in this subdirectory
        for i, mask_name in enumerate(masks):  
            if mask_name.endswith(".png"):   #Only read png images... (masks in this dataset)
               
                mask = cv2.imread(path+"/"+mask_name, 1)  #Read each image as Grey (or color but remember to map each color to an integer)
                mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                mask = Image.fromarray(mask)
                mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #mask = mask.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                mask = np.array(mask)             
       
                #Extract patches from each image
                print("Now patchifying mask:", path+"/"+mask_name)
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        
                        single_patch_mask = patches_mask[i,j,:,:]
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                        single_patch_mask = single_patch_mask[0] #Drop the extra unecessary dimension that patchify adds.                               
                        mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
# Out:
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/images/image_part_001.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_002.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_006.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_005.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_003.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_004.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_007.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_009.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_008.jpg
# Now patchifying image: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/images/image_part_001.jpg
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 7/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 8/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 2/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 5/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 3/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 6/masks/image_part_004.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_001.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_003.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_006.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_002.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_008.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_007.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_009.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_005.png
# Now patchifying mask: /kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 4/masks/image_part_004.png

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %%
###########################################################################
"""
RGB to HEX: (Hexadecimel --> base 16)
This number divided by sixteen (integer division; ignoring any remainder) gives 
the first hexadecimal digit (between 0 and F, where the letters A to F represent 
the numbers 10 to 15). The remainder gives the second hexadecimal digit. 
0-9 --> 0-9
10-15 --> A-F

Example: RGB --> R=201, G=, B=

R = 201/16 = 12 with remainder of 9. So hex code for R is C9 (remember C=12)

Calculating RGB from HEX: #3C1098
3C = 3*16 + 12 = 60
10 = 1*16 + 0 = 16
98 = 9*16 + 8 = 152

"""
#Convert HEX to RGB array
# Try the following to understand how python handles hex values...
a=int('3C', 16)  #3C with base 16. Should return 60. 
print(a)
#Do the same for all RGB channels in each hex code to convert to RGB
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#') 
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#') 
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#') 
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#') 
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

label = single_patch_mask

# Now replace RGB to integer values to be used as labels.
#Find pixels with combination of RGB for the above defined arrays...
#if matches then replace all values in that pixel with a specific integer
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5
    
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return label_seg

labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)   
labels = np.expand_dims(labels, axis=3)
 

print("Unique labels in label dataset are: ", np.unique(labels))
# Out:
# 60
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
#Another Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K

def jacard_coef(y_true, y_pred):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection + 1.0)



################################################################
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
 
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
    
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    
    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    #model.summary()
    
    return model

# %%
import tensorflow as tf
n_classes = len(np.unique(labels))
from keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)


#######################################
#Parameters for model
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
# from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', np.unique(np.ravel(labels,order='C')), 
#                               np.ravel(labels,order='C'))
# print(weights)

weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# from simple_multi_unet_model import multi_unet_model, jacard_coef  

metrics=['accuracy', jacard_coef]

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
model.summary()


history1 = model.fit(X_train, y_train, 
                    batch_size = 16, 
                    verbose=1, 
                    epochs=100, 
                    validation_data=(X_test, y_test), 
                    shuffle=False)

#Minmaxscaler
#With weights...[0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]   in Dice loss
#With focal loss only, after 100 epochs val jacard is: 0.62  (Mean IoU: 0.6)            
#With dice loss only, after 100 epochs val jacard is: 0.74 (Reached 0.7 in 40 epochs)
#With dice + 5 focal, after 100 epochs val jacard is: 0.711 (Mean IoU: 0.611)
##With dice + 1 focal, after 100 epochs val jacard is: 0.75 (Mean IoU: 0.62)
#Using categorical crossentropy as loss: 0.71

##With calculated weights in Dice loss.    
#With dice loss only, after 100 epochs val jacard is: 0.672 (0.52 iou)


##Standardscaler 
#Using categorical crossentropy as loss: 0.677

#model.save('models/satellite_standard_unet_100epochs_7May2021.hdf5')
############################################################
#TRY ANOTHE MODEL - WITH PRETRINED WEIGHTS
#Resnet backbone
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

# preprocess input
X_train_prepr = preprocess_input(X_train)
X_test_prepr = preprocess_input(X_test)

# define model
model_resnet_backbone = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation='softmax')

# compile keras model with defined optimozer, loss and metrics
#model_resnet_backbone.compile(optimizer='adam', loss=focal_loss, metrics=metrics)
model_resnet_backbone.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)

print(model_resnet_backbone.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        102 │ conv2d_17[0][0]   │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,190 (7.41 MB)
#  Trainable params: 1,941,190 (7.41 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714360783.376779     130 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 96s 734ms/step - accuracy: 0.3771 - jacard_coef: 0.1388 - loss: 1.0228 - val_accuracy: 0.5090 - val_jacard_coef: 0.1927 - val_loss: 1.0067
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 143ms/step - accuracy: 0.5533 - jacard_coef: 0.2052 - loss: 1.0055 - val_accuracy: 0.5092 - val_jacard_coef: 0.2003 - val_loss: 1.0049
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.5586 - jacard_coef: 0.2094 - loss: 1.0032 - val_accuracy: 0.5439 - val_jacard_coef: 0.2164 - val_loss: 1.0003
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.5711 - jacard_coef: 0.2231 - loss: 1.0003 - val_accuracy: 0.5456 - val_jacard_coef: 0.2058 - val_loss: 0.9992
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.5719 - jacard_coef: 0.2286 - loss: 0.9990 - val_accuracy: 0.5470 - val_jacard_coef: 0.2075 - val_loss: 0.9987
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5723 - jacard_coef: 0.2327 - loss: 0.9982 - val_accuracy: 0.5394 - val_jacard_coef: 0.2020 - val_loss: 1.0001
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5744 - jacard_coef: 0.2323 - loss: 0.9980 - val_accuracy: 0.5453 - val_jacard_coef: 0.2082 - val_loss: 0.9985
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5749 - jacard_coef: 0.2349 - loss: 0.9971 - val_accuracy: 0.5470 - val_jacard_coef: 0.2147 - val_loss: 0.9986
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5792 - jacard_coef: 0.2374 - loss: 0.9966 - val_accuracy: 0.5431 - val_jacard_coef: 0.2139 - val_loss: 0.9976
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5781 - jacard_coef: 0.2409 - loss: 0.9959 - val_accuracy: 0.5420 - val_jacard_coef: 0.2130 - val_loss: 0.9976
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.5799 - jacard_coef: 0.2418 - loss: 0.9957 - val_accuracy: 0.5454 - val_jacard_coef: 0.2174 - val_loss: 0.9972
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5799 - jacard_coef: 0.2416 - loss: 0.9962 - val_accuracy: 0.5420 - val_jacard_coef: 0.2193 - val_loss: 0.9976
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5761 - jacard_coef: 0.2427 - loss: 0.9959 - val_accuracy: 0.5419 - val_jacard_coef: 0.2440 - val_loss: 0.9982
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5734 - jacard_coef: 0.2437 - loss: 0.9954 - val_accuracy: 0.5446 - val_jacard_coef: 0.2482 - val_loss: 0.9980
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5745 - jacard_coef: 0.2501 - loss: 0.9954 - val_accuracy: 0.5473 - val_jacard_coef: 0.2461 - val_loss: 0.9969
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5744 - jacard_coef: 0.2518 - loss: 0.9948 - val_accuracy: 0.5480 - val_jacard_coef: 0.2459 - val_loss: 0.9970
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5760 - jacard_coef: 0.2489 - loss: 0.9952 - val_accuracy: 0.5443 - val_jacard_coef: 0.2340 - val_loss: 0.9977
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5752 - jacard_coef: 0.2457 - loss: 0.9947 - val_accuracy: 0.5459 - val_jacard_coef: 0.2126 - val_loss: 0.9971
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5757 - jacard_coef: 0.2477 - loss: 0.9946 - val_accuracy: 0.5435 - val_jacard_coef: 0.2040 - val_loss: 0.9977
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5781 - jacard_coef: 0.2443 - loss: 0.9941 - val_accuracy: 0.5453 - val_jacard_coef: 0.2363 - val_loss: 0.9966
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5787 - jacard_coef: 0.2515 - loss: 0.9938 - val_accuracy: 0.5446 - val_jacard_coef: 0.2245 - val_loss: 0.9965
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5778 - jacard_coef: 0.2486 - loss: 0.9934 - val_accuracy: 0.5439 - val_jacard_coef: 0.2290 - val_loss: 0.9960
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5775 - jacard_coef: 0.2491 - loss: 0.9939 - val_accuracy: 0.5455 - val_jacard_coef: 0.2349 - val_loss: 0.9961
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5821 - jacard_coef: 0.2524 - loss: 0.9935 - val_accuracy: 0.5350 - val_jacard_coef: 0.2210 - val_loss: 0.9966
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5784 - jacard_coef: 0.2509 - loss: 0.9933 - val_accuracy: 0.5375 - val_jacard_coef: 0.2284 - val_loss: 0.9960
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5784 - jacard_coef: 0.2532 - loss: 0.9933 - val_accuracy: 0.5378 - val_jacard_coef: 0.2301 - val_loss: 0.9957
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5806 - jacard_coef: 0.2532 - loss: 0.9930 - val_accuracy: 0.5345 - val_jacard_coef: 0.2253 - val_loss: 0.9959
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5807 - jacard_coef: 0.2529 - loss: 0.9932 - val_accuracy: 0.5370 - val_jacard_coef: 0.2270 - val_loss: 0.9963
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5859 - jacard_coef: 0.2535 - loss: 0.9926 - val_accuracy: 0.5362 - val_jacard_coef: 0.2320 - val_loss: 0.9953
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5795 - jacard_coef: 0.2554 - loss: 0.9926 - val_accuracy: 0.5386 - val_jacard_coef: 0.2168 - val_loss: 0.9973
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5833 - jacard_coef: 0.2525 - loss: 0.9931 - val_accuracy: 0.5329 - val_jacard_coef: 0.2004 - val_loss: 1.0000
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5812 - jacard_coef: 0.2418 - loss: 0.9936 - val_accuracy: 0.5434 - val_jacard_coef: 0.2358 - val_loss: 0.9958
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5877 - jacard_coef: 0.2576 - loss: 0.9920 - val_accuracy: 0.5316 - val_jacard_coef: 0.2292 - val_loss: 0.9955
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5860 - jacard_coef: 0.2568 - loss: 0.9917 - val_accuracy: 0.5292 - val_jacard_coef: 0.2076 - val_loss: 0.9986
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5870 - jacard_coef: 0.2509 - loss: 0.9922 - val_accuracy: 0.5114 - val_jacard_coef: 0.2037 - val_loss: 0.9996
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5879 - jacard_coef: 0.2522 - loss: 0.9921 - val_accuracy: 0.5411 - val_jacard_coef: 0.2414 - val_loss: 0.9955
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5874 - jacard_coef: 0.2568 - loss: 0.9923 - val_accuracy: 0.5156 - val_jacard_coef: 0.2043 - val_loss: 0.9988
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.5862 - jacard_coef: 0.2473 - loss: 0.9920 - val_accuracy: 0.4958 - val_jacard_coef: 0.2043 - val_loss: 0.9983
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5907 - jacard_coef: 0.2508 - loss: 0.9915 - val_accuracy: 0.5439 - val_jacard_coef: 0.2266 - val_loss: 0.9956
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5921 - jacard_coef: 0.2562 - loss: 0.9921 - val_accuracy: 0.5192 - val_jacard_coef: 0.2024 - val_loss: 0.9994
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5891 - jacard_coef: 0.2480 - loss: 0.9919 - val_accuracy: 0.5298 - val_jacard_coef: 0.2061 - val_loss: 0.9993
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5896 - jacard_coef: 0.2464 - loss: 0.9926 - val_accuracy: 0.5298 - val_jacard_coef: 0.2077 - val_loss: 0.9980
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5930 - jacard_coef: 0.2524 - loss: 0.9906 - val_accuracy: 0.5083 - val_jacard_coef: 0.2064 - val_loss: 0.9982
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5946 - jacard_coef: 0.2523 - loss: 0.9907 - val_accuracy: 0.5319 - val_jacard_coef: 0.2283 - val_loss: 0.9950
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5960 - jacard_coef: 0.2608 - loss: 0.9904 - val_accuracy: 0.5344 - val_jacard_coef: 0.2322 - val_loss: 0.9949
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5909 - jacard_coef: 0.2623 - loss: 0.9905 - val_accuracy: 0.5087 - val_jacard_coef: 0.2144 - val_loss: 0.9968
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5972 - jacard_coef: 0.2558 - loss: 0.9900 - val_accuracy: 0.5079 - val_jacard_coef: 0.2030 - val_loss: 0.9998
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5933 - jacard_coef: 0.2542 - loss: 0.9904 - val_accuracy: 0.5223 - val_jacard_coef: 0.2133 - val_loss: 0.9972
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6027 - jacard_coef: 0.2592 - loss: 0.9890 - val_accuracy: 0.5072 - val_jacard_coef: 0.2070 - val_loss: 0.9993
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5980 - jacard_coef: 0.2577 - loss: 0.9893 - val_accuracy: 0.5289 - val_jacard_coef: 0.2264 - val_loss: 0.9951
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5996 - jacard_coef: 0.2643 - loss: 0.9888 - val_accuracy: 0.5155 - val_jacard_coef: 0.2205 - val_loss: 0.9965
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.5948 - jacard_coef: 0.2602 - loss: 0.9892 - val_accuracy: 0.5045 - val_jacard_coef: 0.2066 - val_loss: 0.9992
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5977 - jacard_coef: 0.2581 - loss: 0.9890 - val_accuracy: 0.5297 - val_jacard_coef: 0.2262 - val_loss: 0.9962
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6014 - jacard_coef: 0.2639 - loss: 0.9881 - val_accuracy: 0.5121 - val_jacard_coef: 0.2207 - val_loss: 0.9963
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.6000 - jacard_coef: 0.2666 - loss: 0.9878 - val_accuracy: 0.5298 - val_jacard_coef: 0.2321 - val_loss: 0.9951
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.5985 - jacard_coef: 0.2655 - loss: 0.9879 - val_accuracy: 0.4859 - val_jacard_coef: 0.2137 - val_loss: 0.9986
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6009 - jacard_coef: 0.2639 - loss: 0.9876 - val_accuracy: 0.4626 - val_jacard_coef: 0.2032 - val_loss: 1.0003
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.6007 - jacard_coef: 0.2611 - loss: 0.9876 - val_accuracy: 0.5177 - val_jacard_coef: 0.2231 - val_loss: 0.9963
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6052 - jacard_coef: 0.2658 - loss: 0.9869 - val_accuracy: 0.4860 - val_jacard_coef: 0.2189 - val_loss: 0.9977
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6038 - jacard_coef: 0.2680 - loss: 0.9866 - val_accuracy: 0.5204 - val_jacard_coef: 0.2341 - val_loss: 0.9960
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6044 - jacard_coef: 0.2717 - loss: 0.9862 - val_accuracy: 0.5286 - val_jacard_coef: 0.2311 - val_loss: 0.9961
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6054 - jacard_coef: 0.2715 - loss: 0.9861 - val_accuracy: 0.5211 - val_jacard_coef: 0.2305 - val_loss: 0.9967
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6066 - jacard_coef: 0.2726 - loss: 0.9856 - val_accuracy: 0.5222 - val_jacard_coef: 0.2312 - val_loss: 0.9967
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6102 - jacard_coef: 0.2765 - loss: 0.9850 - val_accuracy: 0.5149 - val_jacard_coef: 0.2289 - val_loss: 0.9981
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6129 - jacard_coef: 0.2782 - loss: 0.9846 - val_accuracy: 0.5210 - val_jacard_coef: 0.2329 - val_loss: 0.9976
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6119 - jacard_coef: 0.2793 - loss: 0.9842 - val_accuracy: 0.5269 - val_jacard_coef: 0.2344 - val_loss: 0.9970
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6141 - jacard_coef: 0.2828 - loss: 0.9836 - val_accuracy: 0.4627 - val_jacard_coef: 0.2097 - val_loss: 1.0012
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6074 - jacard_coef: 0.2734 - loss: 0.9848 - val_accuracy: 0.5024 - val_jacard_coef: 0.2165 - val_loss: 1.0018
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6114 - jacard_coef: 0.2786 - loss: 0.9841 - val_accuracy: 0.5161 - val_jacard_coef: 0.2212 - val_loss: 0.9994
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6153 - jacard_coef: 0.2794 - loss: 0.9838 - val_accuracy: 0.5069 - val_jacard_coef: 0.2167 - val_loss: 1.0008
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6145 - jacard_coef: 0.2785 - loss: 0.9834 - val_accuracy: 0.5132 - val_jacard_coef: 0.2224 - val_loss: 1.0008
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6109 - jacard_coef: 0.2769 - loss: 0.9841 - val_accuracy: 0.4989 - val_jacard_coef: 0.2182 - val_loss: 1.0047
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6099 - jacard_coef: 0.2785 - loss: 0.9841 - val_accuracy: 0.5322 - val_jacard_coef: 0.2321 - val_loss: 0.9973
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6125 - jacard_coef: 0.2812 - loss: 0.9833 - val_accuracy: 0.5345 - val_jacard_coef: 0.2386 - val_loss: 0.9969
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6160 - jacard_coef: 0.2895 - loss: 0.9822 - val_accuracy: 0.5270 - val_jacard_coef: 0.2319 - val_loss: 0.9973
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6211 - jacard_coef: 0.2898 - loss: 0.9808 - val_accuracy: 0.5427 - val_jacard_coef: 0.2347 - val_loss: 0.9976
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6224 - jacard_coef: 0.2913 - loss: 0.9802 - val_accuracy: 0.5383 - val_jacard_coef: 0.2359 - val_loss: 0.9961
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6227 - jacard_coef: 0.2924 - loss: 0.9797 - val_accuracy: 0.5316 - val_jacard_coef: 0.2349 - val_loss: 0.9983
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6223 - jacard_coef: 0.2918 - loss: 0.9803 - val_accuracy: 0.5267 - val_jacard_coef: 0.2255 - val_loss: 0.9995
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6264 - jacard_coef: 0.2927 - loss: 0.9790 - val_accuracy: 0.5338 - val_jacard_coef: 0.2297 - val_loss: 0.9998
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6280 - jacard_coef: 0.2929 - loss: 0.9792 - val_accuracy: 0.5341 - val_jacard_coef: 0.2363 - val_loss: 1.0026
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6281 - jacard_coef: 0.2987 - loss: 0.9790 - val_accuracy: 0.5151 - val_jacard_coef: 0.2156 - val_loss: 1.0032
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6246 - jacard_coef: 0.2862 - loss: 0.9812 - val_accuracy: 0.5039 - val_jacard_coef: 0.2228 - val_loss: 1.0045
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6184 - jacard_coef: 0.2899 - loss: 0.9821 - val_accuracy: 0.5133 - val_jacard_coef: 0.2321 - val_loss: 1.0018
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6323 - jacard_coef: 0.3018 - loss: 0.9779 - val_accuracy: 0.5150 - val_jacard_coef: 0.2226 - val_loss: 1.0023
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6377 - jacard_coef: 0.3001 - loss: 0.9770 - val_accuracy: 0.5202 - val_jacard_coef: 0.2243 - val_loss: 1.0042
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6391 - jacard_coef: 0.3052 - loss: 0.9760 - val_accuracy: 0.5104 - val_jacard_coef: 0.2286 - val_loss: 1.0070
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6455 - jacard_coef: 0.3097 - loss: 0.9751 - val_accuracy: 0.5135 - val_jacard_coef: 0.2298 - val_loss: 1.0085
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6453 - jacard_coef: 0.3113 - loss: 0.9749 - val_accuracy: 0.4969 - val_jacard_coef: 0.2202 - val_loss: 1.0081
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6380 - jacard_coef: 0.3072 - loss: 0.9765 - val_accuracy: 0.5145 - val_jacard_coef: 0.2297 - val_loss: 1.0048
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6430 - jacard_coef: 0.3122 - loss: 0.9752 - val_accuracy: 0.5060 - val_jacard_coef: 0.2254 - val_loss: 1.0068
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6394 - jacard_coef: 0.3108 - loss: 0.9755 - val_accuracy: 0.4848 - val_jacard_coef: 0.2152 - val_loss: 1.0099
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6394 - jacard_coef: 0.3088 - loss: 0.9762 - val_accuracy: 0.4906 - val_jacard_coef: 0.2122 - val_loss: 1.0090
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6435 - jacard_coef: 0.3084 - loss: 0.9753 - val_accuracy: 0.4900 - val_jacard_coef: 0.2171 - val_loss: 1.0107
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6399 - jacard_coef: 0.3095 - loss: 0.9755 - val_accuracy: 0.5006 - val_jacard_coef: 0.2181 - val_loss: 1.0108
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6492 - jacard_coef: 0.3133 - loss: 0.9741 - val_accuracy: 0.4855 - val_jacard_coef: 0.2140 - val_loss: 1.0135
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6477 - jacard_coef: 0.3162 - loss: 0.9738 - val_accuracy: 0.5001 - val_jacard_coef: 0.2189 - val_loss: 1.0091
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6442 - jacard_coef: 0.3073 - loss: 0.9759 - val_accuracy: 0.5111 - val_jacard_coef: 0.2228 - val_loss: 1.0082
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6460 - jacard_coef: 0.3098 - loss: 0.9749 - val_accuracy: 0.5123 - val_jacard_coef: 0.2229 - val_loss: 1.0068
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6501 - jacard_coef: 0.3174 - loss: 0.9728 - val_accuracy: 0.5103 - val_jacard_coef: 0.2197 - val_loss: 1.0133
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85521592/85521592 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ data (InputLayer)   │ (None, None,      │          0 │ -                 │
# │                     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_data             │ (None, None,      │          9 │ data[0][0]        │
# │ (BatchNormalizatio… │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, None,      │          0 │ bn_data[0][0]     │
# │ (ZeroPadding2D)     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv0 (Conv2D)      │ (None, None,      │      9,408 │ zero_padding2d[0… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn0                 │ (None, None,      │        256 │ conv0[0][0]       │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu0 (Activation)  │ (None, None,      │          0 │ bn0[0][0]         │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, None,      │          0 │ relu0[0][0]       │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pooling0            │ (None, None,      │          0 │ zero_padding2d_1… │
# │ (MaxPooling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_bn1    │ (None, None,      │        256 │ pooling0[0][0]    │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_relu1  │ (None, None,      │          0 │ stage1_unit1_bn1… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, None,      │          0 │ stage1_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_conv1  │ (None, None,      │     36,864 │ zero_padding2d_2… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_bn2    │ (None, None,      │        256 │ stage1_unit1_con… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_relu2  │ (None, None,      │          0 │ stage1_unit1_bn2… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, None,      │          0 │ stage1_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_conv2  │ (None, None,      │     36,864 │ zero_padding2d_3… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_sc     │ (None, None,      │      4,096 │ stage1_unit1_rel… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, None,      │          0 │ stage1_unit1_con… │
# │                     │ None, 64)         │            │ stage1_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_bn1    │ (None, None,      │        256 │ add[0][0]         │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_relu1  │ (None, None,      │          0 │ stage1_unit2_bn1… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_4    │ (None, None,      │          0 │ stage1_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_conv1  │ (None, None,      │     36,864 │ zero_padding2d_4… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_bn2    │ (None, None,      │        256 │ stage1_unit2_con… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_relu2  │ (None, None,      │          0 │ stage1_unit2_bn2… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_5    │ (None, None,      │          0 │ stage1_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_conv2  │ (None, None,      │     36,864 │ zero_padding2d_5… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, None,      │          0 │ stage1_unit2_con… │
# │                     │ None, 64)         │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_bn1    │ (None, None,      │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_relu1  │ (None, None,      │          0 │ stage1_unit3_bn1… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_6    │ (None, None,      │          0 │ stage1_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_conv1  │ (None, None,      │     36,864 │ zero_padding2d_6… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_bn2    │ (None, None,      │        256 │ stage1_unit3_con… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_relu2  │ (None, None,      │          0 │ stage1_unit3_bn2… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_7    │ (None, None,      │          0 │ stage1_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_conv2  │ (None, None,      │     36,864 │ zero_padding2d_7… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, None,      │          0 │ stage1_unit3_con… │
# │                     │ None, 64)         │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_bn1    │ (None, None,      │        256 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_relu1  │ (None, None,      │          0 │ stage2_unit1_bn1… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_8    │ (None, None,      │          0 │ stage2_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_conv1  │ (None, None,      │     73,728 │ zero_padding2d_8… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_bn2    │ (None, None,      │        512 │ stage2_unit1_con… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_relu2  │ (None, None,      │          0 │ stage2_unit1_bn2… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_9    │ (None, None,      │          0 │ stage2_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_conv2  │ (None, None,      │    147,456 │ zero_padding2d_9… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_sc     │ (None, None,      │      8,192 │ stage2_unit1_rel… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, None,      │          0 │ stage2_unit1_con… │
# │                     │ None, 128)        │            │ stage2_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_bn1    │ (None, None,      │        512 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_relu1  │ (None, None,      │          0 │ stage2_unit2_bn1… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_10   │ (None, None,      │          0 │ stage2_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_conv1  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_bn2    │ (None, None,      │        512 │ stage2_unit2_con… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_relu2  │ (None, None,      │          0 │ stage2_unit2_bn2… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_11   │ (None, None,      │          0 │ stage2_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_conv2  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, None,      │          0 │ stage2_unit2_con… │
# │                     │ None, 128)        │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_bn1    │ (None, None,      │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_relu1  │ (None, None,      │          0 │ stage2_unit3_bn1… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_12   │ (None, None,      │          0 │ stage2_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_conv1  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_bn2    │ (None, None,      │        512 │ stage2_unit3_con… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_relu2  │ (None, None,      │          0 │ stage2_unit3_bn2… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_13   │ (None, None,      │          0 │ stage2_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_conv2  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, None,      │          0 │ stage2_unit3_con… │
# │                     │ None, 128)        │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_bn1    │ (None, None,      │        512 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_relu1  │ (None, None,      │          0 │ stage2_unit4_bn1… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_14   │ (None, None,      │          0 │ stage2_unit4_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_conv1  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_bn2    │ (None, None,      │        512 │ stage2_unit4_con… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_relu2  │ (None, None,      │          0 │ stage2_unit4_bn2… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_15   │ (None, None,      │          0 │ stage2_unit4_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_conv2  │ (None, None,      │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, None,      │          0 │ stage2_unit4_con… │
# │                     │ None, 128)        │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_bn1    │ (None, None,      │        512 │ add_6[0][0]       │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_relu1  │ (None, None,      │          0 │ stage3_unit1_bn1… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_16   │ (None, None,      │          0 │ stage3_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_conv1  │ (None, None,      │    294,912 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_bn2    │ (None, None,      │      1,024 │ stage3_unit1_con… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_relu2  │ (None, None,      │          0 │ stage3_unit1_bn2… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_17   │ (None, None,      │          0 │ stage3_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_conv2  │ (None, None,      │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_sc     │ (None, None,      │     32,768 │ stage3_unit1_rel… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, None,      │          0 │ stage3_unit1_con… │
# │                     │ None, 256)        │            │ stage3_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_bn1    │ (None, None,      │      1,024 │ add_7[0][0]       │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_relu1  │ (None, None,      │          0 │ stage3_unit2_bn1… │
# │ (Activation)        │ None, 256)        │            │                   │
# ...
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_conv1  │ (None, None,      │  1,179,648 │ zero_padding2d_2… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_bn2    │ (None, None,      │      2,048 │ stage4_unit1_con… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_relu2  │ (None, None,      │          0 │ stage4_unit1_bn2… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_29   │ (None, None,      │          0 │ stage4_unit1_rel… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_conv2  │ (None, None,      │  2,359,296 │ zero_padding2d_2… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_sc     │ (None, None,      │    131,072 │ stage4_unit1_rel… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, None,      │          0 │ stage4_unit1_con… │
# │                     │ None, 512)        │            │ stage4_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_bn1    │ (None, None,      │      2,048 │ add_13[0][0]      │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_relu1  │ (None, None,      │          0 │ stage4_unit2_bn1… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_30   │ (None, None,      │          0 │ stage4_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_conv1  │ (None, None,      │  2,359,296 │ zero_padding2d_3… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_bn2    │ (None, None,      │      2,048 │ stage4_unit2_con… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_relu2  │ (None, None,      │          0 │ stage4_unit2_bn2… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_31   │ (None, None,      │          0 │ stage4_unit2_rel… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_conv2  │ (None, None,      │  2,359,296 │ zero_padding2d_3… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, None,      │          0 │ stage4_unit2_con… │
# │                     │ None, 512)        │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_bn1    │ (None, None,      │      2,048 │ add_14[0][0]      │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_relu1  │ (None, None,      │          0 │ stage4_unit3_bn1… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_32   │ (None, None,      │          0 │ stage4_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_conv1  │ (None, None,      │  2,359,296 │ zero_padding2d_3… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_bn2    │ (None, None,      │      2,048 │ stage4_unit3_con… │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_relu2  │ (None, None,      │          0 │ stage4_unit3_bn2… │
# │ (Activation)        │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_33   │ (None, None,      │          0 │ stage4_unit3_rel… │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_conv2  │ (None, None,      │  2,359,296 │ zero_padding2d_3… │
# │ (Conv2D)            │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, None,      │          0 │ stage4_unit3_con… │
# │                     │ None, 512)        │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, None,      │      2,048 │ add_15[0][0]      │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, None,      │          0 │ bn1[0][0]         │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0_ups… │ (None, None,      │          0 │ relu1[0][0]       │
# │ (UpSampling2D)      │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0_con… │ (None, None,      │          0 │ decoder_stage0_u… │
# │ (Concatenate)       │ None, 768)        │            │ stage4_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_co… │ (None, None,      │  1,769,472 │ decoder_stage0_c… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_bn  │ (None, None,      │      1,024 │ decoder_stage0a_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_re… │ (None, None,      │          0 │ decoder_stage0a_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_co… │ (None, None,      │    589,824 │ decoder_stage0a_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_bn  │ (None, None,      │      1,024 │ decoder_stage0b_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_re… │ (None, None,      │          0 │ decoder_stage0b_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1_ups… │ (None, None,      │          0 │ decoder_stage0b_… │
# │ (UpSampling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1_con… │ (None, None,      │          0 │ decoder_stage1_u… │
# │ (Concatenate)       │ None, 384)        │            │ stage3_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_co… │ (None, None,      │    442,368 │ decoder_stage1_c… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_bn  │ (None, None,      │        512 │ decoder_stage1a_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_re… │ (None, None,      │          0 │ decoder_stage1a_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_co… │ (None, None,      │    147,456 │ decoder_stage1a_… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_bn  │ (None, None,      │        512 │ decoder_stage1b_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_re… │ (None, None,      │          0 │ decoder_stage1b_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2_ups… │ (None, None,      │          0 │ decoder_stage1b_… │
# │ (UpSampling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2_con… │ (None, None,      │          0 │ decoder_stage2_u… │
# │ (Concatenate)       │ None, 192)        │            │ stage2_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_co… │ (None, None,      │    110,592 │ decoder_stage2_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_bn  │ (None, None,      │        256 │ decoder_stage2a_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_re… │ (None, None,      │          0 │ decoder_stage2a_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_co… │ (None, None,      │     36,864 │ decoder_stage2a_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_bn  │ (None, None,      │        256 │ decoder_stage2b_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_re… │ (None, None,      │          0 │ decoder_stage2b_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3_ups… │ (None, None,      │          0 │ decoder_stage2b_… │
# │ (UpSampling2D)      │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3_con… │ (None, None,      │          0 │ decoder_stage3_u… │
# │ (Concatenate)       │ None, 128)        │            │ relu0[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_co… │ (None, None,      │     36,864 │ decoder_stage3_c… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_bn  │ (None, None,      │        128 │ decoder_stage3a_… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_re… │ (None, None,      │          0 │ decoder_stage3a_… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_co… │ (None, None,      │      9,216 │ decoder_stage3a_… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_bn  │ (None, None,      │        128 │ decoder_stage3b_… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_re… │ (None, None,      │          0 │ decoder_stage3b_… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4_ups… │ (None, None,      │          0 │ decoder_stage3b_… │
# │ (UpSampling2D)      │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_co… │ (None, None,      │      4,608 │ decoder_stage4_u… │
# │ (Conv2D)            │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_bn  │ (None, None,      │         64 │ decoder_stage4a_… │
# │ (BatchNormalizatio… │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_re… │ (None, None,      │          0 │ decoder_stage4a_… │
# │ (Activation)        │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_co… │ (None, None,      │      2,304 │ decoder_stage4a_… │
# │ (Conv2D)            │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_bn  │ (None, None,      │         64 │ decoder_stage4b_… │
# │ (BatchNormalizatio… │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_re… │ (None, None,      │          0 │ decoder_stage4b_… │
# │ (Activation)        │ None, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv (Conv2D) │ (None, None,      │        870 │ decoder_stage4b_… │
# │                     │ None, 6)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, None,      │          0 │ final_conv[0][0]  │
# │ (Activation)        │ None, 6)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,456,879 (93.30 MB)
#  Trainable params: 24,439,529 (93.23 MB)
#  Non-trainable params: 17,350 (67.77 KB)
# None

# %%
#plot the training and validation accuracy and loss at each epoch
history = history1

plt.figure(figsize=(12,8))

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss',marker='o')
plt.plot(epochs, val_loss, 'r', label='Validation loss',marker='^')
# plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0.97,1.05)
plt.legend()
plt.show()

# %%
acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.figure(figsize=(12,8))

plt.plot(epochs, acc, 'y', label='Training IoU',marker='o')
plt.plot(epochs, val_acc, 'r', label='Validation IoU', marker='^')
# plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
model.save('models/satellite_standard_unet_100epochs.hdf5')

# %%
from keras.models import load_model
# model = load_model("/kaggle/working/models/satellite_standard_unet_100epochs.hdf5",
#                    custom_objects={'dice_loss_plus_2focal_loss': total_loss,
#                                    'jacard_coef':jacard_coef})

#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step

# %%
#Using built in keras function for IoU
from keras.metrics import MeanIoU
n_classes = 6
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.16432275

# %%
#Minmaxscaler
#With weights...[0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]   in Dice loss
#With focal loss only, after 100 epochs val jacard is:               
#With dice + 5 focal, after 100 epochs val jacard is: 0.73 (reached 0.71 in 40 epochs. So faster training but not better result. )
##With dice + 1 focal, after 100 epochs val jacard is:   
    ##Using categorical crossentropy as loss: 0.755 (100 epochs)
#With calc. weights supplied to model.fit: 
 
#Standard scaler
#Using categorical crossentropy as loss: 0.74

import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
#####################################################################
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# history2=model_resnet_backbone.fit(X_train_prepr, 
#           y_train,
#           batch_size=16, 
#           epochs=100,
#           verbose=1,
#           validation_data=(X_test_prepr, y_test))

#Minmaxscaler
#With weights...[0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]   in Dice loss
#With focal loss only, after 100 epochs val jacard is:               
#With dice + 5 focal, after 100 epochs val jacard is: 0.73 (reached 0.71 in 40 epochs. So faster training but not better result. )
##With dice + 1 focal, after 100 epochs val jacard is:   
    ##Using categorical crossentropy as loss: 0.755 (100 epochs)
#With calc. weights supplied to model.fit: 
 
#Standard scaler
#Using categorical crossentropy as loss: 0.74

import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()

#####################################################################
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
import random
# test_img_number = random.randint(0, len(X_test))
test_img ='/kaggle/input/semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg'
# ground_truth=y_test_argmax[test_img_number]
# #test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 7
#       4 # ground_truth=y_test_argmax[test_img_number]
#       5 # #test_img_norm=test_img[:,:,0][:,:,None]
#       6 test_img_input=np.expand_dims(test_img, 0)
# ----> 7 prediction = (model.predict(test_img_input))
#       8 predicted_img=np.argmax(prediction, axis=3)[0,:,:]
#      11 plt.figure(figsize=(12, 8))
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/optree/ops.py:594, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     592 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     593 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 594 return treespec.unflatten(map(func, *flat_args))
#
# ValueError: Invalid dtype: str3712

# %%
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
history2=model_resnet_backbone.fit(X_train_prepr, 
          y_train,
          batch_size=16, 
          epochs=100,
          verbose=1,
          validation_data=(X_test_prepr, y_test))

#Minmaxscaler
#With weights...[0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]   in Dice loss
#With focal loss only, after 100 epochs val jacard is:               
#With dice + 5 focal, after 100 epochs val jacard is: 0.73 (reached 0.71 in 40 epochs. So faster training but not better result. )
##With dice + 1 focal, after 100 epochs val jacard is:   
    ##Using categorical crossentropy as loss: 0.755 (100 epochs)
#With calc. weights supplied to model.fit: 
 
#Standard scaler
#Using categorical crossentropy as loss: 0.74


###########################################################
#plot the training and validation accuracy and loss at each epoch
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 128s 942ms/step - accuracy: 0.4458 - jacard_coef: 0.1680 - loss: 1.5342 - val_accuracy: 0.5073 - val_jacard_coef: 0.3412 - val_loss: 92.9706
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 243ms/step - accuracy: 0.5508 - jacard_coef: 0.2307 - loss: 1.2751 - val_accuracy: 0.4515 - val_jacard_coef: 0.1418 - val_loss: 1.5025
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 244ms/step - accuracy: 0.5584 - jacard_coef: 0.2377 - loss: 1.2605 - val_accuracy: 0.5074 - val_jacard_coef: 0.2824 - val_loss: 2.5191
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 245ms/step - accuracy: 0.5434 - jacard_coef: 0.2318 - loss: 1.2723 - val_accuracy: 0.5090 - val_jacard_coef: 0.1637 - val_loss: 1.4193
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.5489 - jacard_coef: 0.2408 - loss: 1.2701 - val_accuracy: 0.5090 - val_jacard_coef: 0.1867 - val_loss: 1.4059
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - accuracy: 0.5520 - jacard_coef: 0.2409 - loss: 1.2633 - val_accuracy: 0.5090 - val_jacard_coef: 0.2002 - val_loss: 1.4006
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.5495 - jacard_coef: 0.2425 - loss: 1.2500 - val_accuracy: 0.5090 - val_jacard_coef: 0.1787 - val_loss: 1.4329
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 249ms/step - accuracy: 0.5674 - jacard_coef: 0.2538 - loss: 1.2222 - val_accuracy: 0.5090 - val_jacard_coef: 0.1758 - val_loss: 1.4101
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 250ms/step - accuracy: 0.5619 - jacard_coef: 0.2424 - loss: 1.2269 - val_accuracy: 0.5090 - val_jacard_coef: 0.1901 - val_loss: 1.4015
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 250ms/step - accuracy: 0.5760 - jacard_coef: 0.2589 - loss: 1.2167 - val_accuracy: 0.5089 - val_jacard_coef: 0.1746 - val_loss: 1.4227
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.5643 - jacard_coef: 0.2454 - loss: 1.2252 - val_accuracy: 0.5090 - val_jacard_coef: 0.2021 - val_loss: 1.3957
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.5597 - jacard_coef: 0.2536 - loss: 1.2355 - val_accuracy: 0.5282 - val_jacard_coef: 0.2411 - val_loss: 1.3452
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - accuracy: 0.5839 - jacard_coef: 0.2570 - loss: 1.1892 - val_accuracy: 0.5091 - val_jacard_coef: 0.2025 - val_loss: 1.4037
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.5987 - jacard_coef: 0.2715 - loss: 1.1682 - val_accuracy: 0.4900 - val_jacard_coef: 0.1739 - val_loss: 1.4324
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.5735 - jacard_coef: 0.2509 - loss: 1.2062 - val_accuracy: 0.5155 - val_jacard_coef: 0.2289 - val_loss: 1.3275
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - accuracy: 0.5633 - jacard_coef: 0.2449 - loss: 1.2399 - val_accuracy: 0.4883 - val_jacard_coef: 0.3099 - val_loss: 118.4505
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5562 - jacard_coef: 0.2447 - loss: 1.2462 - val_accuracy: 0.5487 - val_jacard_coef: 0.2281 - val_loss: 1.2253
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5754 - jacard_coef: 0.2515 - loss: 1.2074 - val_accuracy: 0.4845 - val_jacard_coef: 0.2190 - val_loss: 1.3127
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5865 - jacard_coef: 0.2657 - loss: 1.1736 - val_accuracy: 0.5523 - val_jacard_coef: 0.2417 - val_loss: 1.2306
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5685 - jacard_coef: 0.2516 - loss: 1.2161 - val_accuracy: 0.5126 - val_jacard_coef: 0.2379 - val_loss: 1.2806
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5690 - jacard_coef: 0.2489 - loss: 1.2193 - val_accuracy: 0.5502 - val_jacard_coef: 0.2868 - val_loss: 1.4018
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5650 - jacard_coef: 0.2550 - loss: 1.2177 - val_accuracy: 0.5416 - val_jacard_coef: 0.2224 - val_loss: 1.2899
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5765 - jacard_coef: 0.2513 - loss: 1.2016 - val_accuracy: 0.4794 - val_jacard_coef: 0.2336 - val_loss: 1.2713
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5452 - jacard_coef: 0.2467 - loss: 1.2424 - val_accuracy: 0.5629 - val_jacard_coef: 0.2269 - val_loss: 1.2565
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5769 - jacard_coef: 0.2675 - loss: 1.1898 - val_accuracy: 0.5386 - val_jacard_coef: 0.2564 - val_loss: 1.2581
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5873 - jacard_coef: 0.2683 - loss: 1.1643 - val_accuracy: 0.5400 - val_jacard_coef: 0.2459 - val_loss: 1.2446
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5853 - jacard_coef: 0.2645 - loss: 1.1671 - val_accuracy: 0.5538 - val_jacard_coef: 0.2514 - val_loss: 1.2022
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5908 - jacard_coef: 0.2728 - loss: 1.1596 - val_accuracy: 0.5567 - val_jacard_coef: 0.2434 - val_loss: 1.2231
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5642 - jacard_coef: 0.2581 - loss: 1.1850 - val_accuracy: 0.5449 - val_jacard_coef: 0.2134 - val_loss: 1.2741
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5890 - jacard_coef: 0.2696 - loss: 1.1578 - val_accuracy: 0.5290 - val_jacard_coef: 0.2555 - val_loss: 1.2818
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5972 - jacard_coef: 0.2697 - loss: 1.1524 - val_accuracy: 0.5587 - val_jacard_coef: 0.2683 - val_loss: 1.2223
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 253ms/step - accuracy: 0.5879 - jacard_coef: 0.2677 - loss: 1.1623 - val_accuracy: 0.5389 - val_jacard_coef: 0.3139 - val_loss: 2.0578
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5728 - jacard_coef: 0.2572 - loss: 1.2030 - val_accuracy: 0.5677 - val_jacard_coef: 0.2498 - val_loss: 1.1765
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5858 - jacard_coef: 0.2749 - loss: 1.1602 - val_accuracy: 0.5536 - val_jacard_coef: 0.2774 - val_loss: 2.1563
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5959 - jacard_coef: 0.2777 - loss: 1.1562 - val_accuracy: 0.5251 - val_jacard_coef: 0.2469 - val_loss: 1.2428
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5678 - jacard_coef: 0.2593 - loss: 1.1815 - val_accuracy: 0.5578 - val_jacard_coef: 0.2694 - val_loss: 1.2331
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5854 - jacard_coef: 0.2686 - loss: 1.1753 - val_accuracy: 0.5411 - val_jacard_coef: 0.2697 - val_loss: 1.7330
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5622 - jacard_coef: 0.2558 - loss: 1.2069 - val_accuracy: 0.5568 - val_jacard_coef: 0.2618 - val_loss: 1.3044
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5812 - jacard_coef: 0.2672 - loss: 1.1683 - val_accuracy: 0.5497 - val_jacard_coef: 0.2882 - val_loss: 1.2904
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5697 - jacard_coef: 0.2554 - loss: 1.1965 - val_accuracy: 0.5297 - val_jacard_coef: 0.2669 - val_loss: 1.4898
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5822 - jacard_coef: 0.2648 - loss: 1.1715 - val_accuracy: 0.5492 - val_jacard_coef: 0.2361 - val_loss: 1.2579
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6007 - jacard_coef: 0.2786 - loss: 1.1346 - val_accuracy: 0.5701 - val_jacard_coef: 0.2458 - val_loss: 1.1894
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5967 - jacard_coef: 0.2815 - loss: 1.1393 - val_accuracy: 0.5438 - val_jacard_coef: 0.2447 - val_loss: 1.2084
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5970 - jacard_coef: 0.2818 - loss: 1.1325 - val_accuracy: 0.5387 - val_jacard_coef: 0.2737 - val_loss: 1.3155
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5858 - jacard_coef: 0.2727 - loss: 1.1551 - val_accuracy: 0.5121 - val_jacard_coef: 0.2268 - val_loss: 1.9549
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5908 - jacard_coef: 0.2773 - loss: 1.1591 - val_accuracy: 0.5423 - val_jacard_coef: 0.2298 - val_loss: 1.2333
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5986 - jacard_coef: 0.2833 - loss: 1.1297 - val_accuracy: 0.5531 - val_jacard_coef: 0.2727 - val_loss: 1.9554
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.5643 - jacard_coef: 0.2542 - loss: 1.1946 - val_accuracy: 0.5657 - val_jacard_coef: 0.2447 - val_loss: 1.1927
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6071 - jacard_coef: 0.2909 - loss: 1.1099 - val_accuracy: 0.5385 - val_jacard_coef: 0.2594 - val_loss: 1.2117
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5932 - jacard_coef: 0.2785 - loss: 1.1460 - val_accuracy: 0.2158 - val_jacard_coef: 0.1492 - val_loss: 1.7980
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5882 - jacard_coef: 0.2752 - loss: 1.1538 - val_accuracy: 0.5331 - val_jacard_coef: 0.2590 - val_loss: 1.2408
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5733 - jacard_coef: 0.2648 - loss: 1.1738 - val_accuracy: 0.5360 - val_jacard_coef: 0.3115 - val_loss: 1.6316
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5907 - jacard_coef: 0.2778 - loss: 1.1494 - val_accuracy: 0.5631 - val_jacard_coef: 0.3070 - val_loss: 1.3005
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6030 - jacard_coef: 0.2842 - loss: 1.1300 - val_accuracy: 0.5747 - val_jacard_coef: 0.2855 - val_loss: 1.2015
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5802 - jacard_coef: 0.2659 - loss: 1.1594 - val_accuracy: 0.5469 - val_jacard_coef: 0.2304 - val_loss: 1.2947
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5925 - jacard_coef: 0.2764 - loss: 1.1422 - val_accuracy: 0.5497 - val_jacard_coef: 0.2407 - val_loss: 1.1991
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6063 - jacard_coef: 0.2823 - loss: 1.1226 - val_accuracy: 0.5237 - val_jacard_coef: 0.2052 - val_loss: 1.2767
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.6041 - jacard_coef: 0.2939 - loss: 1.1139 - val_accuracy: 0.5451 - val_jacard_coef: 0.2336 - val_loss: 1.2726
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5850 - jacard_coef: 0.2759 - loss: 1.1457 - val_accuracy: 0.5629 - val_jacard_coef: 0.2643 - val_loss: 1.1778
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5832 - jacard_coef: 0.2813 - loss: 1.1440 - val_accuracy: 0.5368 - val_jacard_coef: 0.2947 - val_loss: 1.3484
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6106 - jacard_coef: 0.2980 - loss: 1.0988 - val_accuracy: 0.4680 - val_jacard_coef: 0.2131 - val_loss: 1.2777
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 257ms/step - accuracy: 0.5871 - jacard_coef: 0.2757 - loss: 1.1446 - val_accuracy: 0.5763 - val_jacard_coef: 0.2938 - val_loss: 1.1949
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5778 - jacard_coef: 0.2726 - loss: 1.1806 - val_accuracy: 0.5492 - val_jacard_coef: 0.2909 - val_loss: 1.2672
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5994 - jacard_coef: 0.2844 - loss: 1.1316 - val_accuracy: 0.4304 - val_jacard_coef: 0.2443 - val_loss: 1.7834
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6060 - jacard_coef: 0.2907 - loss: 1.1109 - val_accuracy: 0.5517 - val_jacard_coef: 0.3042 - val_loss: 1.2838
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.5887 - jacard_coef: 0.2793 - loss: 1.1407 - val_accuracy: 0.5533 - val_jacard_coef: 0.2463 - val_loss: 1.2248
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 253ms/step - accuracy: 0.6046 - jacard_coef: 0.2938 - loss: 1.1073 - val_accuracy: 0.5349 - val_jacard_coef: 0.2956 - val_loss: 1.3445
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6154 - jacard_coef: 0.3002 - loss: 1.0802 - val_accuracy: 0.5254 - val_jacard_coef: 0.2419 - val_loss: 1.3245
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6108 - jacard_coef: 0.2907 - loss: 1.1019 - val_accuracy: 0.5352 - val_jacard_coef: 0.2920 - val_loss: 1.6318
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5858 - jacard_coef: 0.2744 - loss: 1.1757 - val_accuracy: 0.5663 - val_jacard_coef: 0.3038 - val_loss: 1.2459
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5951 - jacard_coef: 0.2875 - loss: 1.1371 - val_accuracy: 0.5489 - val_jacard_coef: 0.2635 - val_loss: 1.2089
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6056 - jacard_coef: 0.2849 - loss: 1.1226 - val_accuracy: 0.5468 - val_jacard_coef: 0.2607 - val_loss: 1.2552
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5896 - jacard_coef: 0.2859 - loss: 1.1398 - val_accuracy: 0.5466 - val_jacard_coef: 0.2718 - val_loss: 1.1892
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.6007 - jacard_coef: 0.2947 - loss: 1.1086 - val_accuracy: 0.5463 - val_jacard_coef: 0.2678 - val_loss: 1.2178
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6045 - jacard_coef: 0.2855 - loss: 1.1138 - val_accuracy: 0.5570 - val_jacard_coef: 0.2847 - val_loss: 1.2128
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 255ms/step - accuracy: 0.6058 - jacard_coef: 0.2997 - loss: 1.1078 - val_accuracy: 0.5668 - val_jacard_coef: 0.2735 - val_loss: 1.1670
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6231 - jacard_coef: 0.3024 - loss: 1.0648 - val_accuracy: 0.5754 - val_jacard_coef: 0.2678 - val_loss: 1.2072
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6121 - jacard_coef: 0.2986 - loss: 1.0919 - val_accuracy: 0.5746 - val_jacard_coef: 0.2400 - val_loss: 1.1765
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6122 - jacard_coef: 0.2959 - loss: 1.0867 - val_accuracy: 0.5234 - val_jacard_coef: 0.2487 - val_loss: 1.3504
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.5952 - jacard_coef: 0.2806 - loss: 1.1306 - val_accuracy: 0.4184 - val_jacard_coef: 0.2091 - val_loss: 1.3887
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6132 - jacard_coef: 0.3040 - loss: 1.1008 - val_accuracy: 0.5365 - val_jacard_coef: 0.2541 - val_loss: 1.3750
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6291 - jacard_coef: 0.3128 - loss: 1.0658 - val_accuracy: 0.5558 - val_jacard_coef: 0.2662 - val_loss: 1.1768
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.5971 - jacard_coef: 0.2919 - loss: 1.1178 - val_accuracy: 0.5015 - val_jacard_coef: 0.2398 - val_loss: 1.3607
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6210 - jacard_coef: 0.3062 - loss: 1.0672 - val_accuracy: 0.5347 - val_jacard_coef: 0.3157 - val_loss: 1.4379
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6227 - jacard_coef: 0.3140 - loss: 1.0570 - val_accuracy: 0.4858 - val_jacard_coef: 0.2507 - val_loss: 1.3376
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6204 - jacard_coef: 0.3012 - loss: 1.0635 - val_accuracy: 0.5569 - val_jacard_coef: 0.2678 - val_loss: 1.2051
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6075 - jacard_coef: 0.2945 - loss: 1.1010 - val_accuracy: 0.5582 - val_jacard_coef: 0.2828 - val_loss: 1.2327
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6187 - jacard_coef: 0.3037 - loss: 1.0844 - val_accuracy: 0.5613 - val_jacard_coef: 0.3121 - val_loss: 1.3216
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 253ms/step - accuracy: 0.6309 - jacard_coef: 0.3142 - loss: 1.0506 - val_accuracy: 0.4984 - val_jacard_coef: 0.2533 - val_loss: 1.4860
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6212 - jacard_coef: 0.3068 - loss: 1.0691 - val_accuracy: 0.5554 - val_jacard_coef: 0.2741 - val_loss: 1.2442
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 253ms/step - accuracy: 0.6295 - jacard_coef: 0.3172 - loss: 1.0468 - val_accuracy: 0.5594 - val_jacard_coef: 0.2904 - val_loss: 1.2381
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6395 - jacard_coef: 0.3262 - loss: 1.0264 - val_accuracy: 0.5565 - val_jacard_coef: 0.2926 - val_loss: 1.3056
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6364 - jacard_coef: 0.3097 - loss: 1.0445 - val_accuracy: 0.5529 - val_jacard_coef: 0.2914 - val_loss: 1.2479
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6358 - jacard_coef: 0.3224 - loss: 1.0218 - val_accuracy: 0.5526 - val_jacard_coef: 0.2650 - val_loss: 1.2090
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6327 - jacard_coef: 0.3248 - loss: 1.0194 - val_accuracy: 0.5075 - val_jacard_coef: 0.2600 - val_loss: 1.2992
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6162 - jacard_coef: 0.3081 - loss: 1.0737 - val_accuracy: 0.5704 - val_jacard_coef: 0.2988 - val_loss: 1.2016
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6441 - jacard_coef: 0.3414 - loss: 1.0036 - val_accuracy: 0.5382 - val_jacard_coef: 0.2877 - val_loss: 1.3769
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6492 - jacard_coef: 0.3382 - loss: 0.9803 - val_accuracy: 0.5440 - val_jacard_coef: 0.2314 - val_loss: 1.2585
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6487 - jacard_coef: 0.3345 - loss: 0.9872 - val_accuracy: 0.5688 - val_jacard_coef: 0.3008 - val_loss: 1.2184
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - accuracy: 0.6057 - jacard_coef: 0.3089 - loss: 1.0824 - val_accuracy: 0.5493 - val_jacard_coef: 0.2897 - val_loss: 1.3037

# %%
history = history2
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12,8))
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss',marker='o')
plt.plot(epochs, val_loss, 'r', label='Validation loss',marker='^')
# plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']
plt.figure(figsize=(12,8))
plt.plot(epochs, acc, 'y', label='Training IoU',marker='o')
plt.plot(epochs, val_acc, 'r', label='Validation IoU',marker='^')
# plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model_resnet_backbone.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model_resnet_backbone.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
